# %%
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from collections import defaultdict
import pandas as pd
from datetime import datetime, date
from lxml import etree as ET
from lxml.builder import E

# %% [markdown]
# # Contemporary Chosun Crawler
# 조선일보 2012, 2013, 2015, 2016, 2017년도 기사를 크롤링합니다.

# %%
y_2012 = date.fromisoformat('2012-01-12')
y_2013 = date.fromisoformat('2013-01-01')
y_2015 = date.fromisoformat('2015-01-01')
y_2016 = date.fromisoformat('2016-01-16')
y_2017 = date.fromisoformat('2017-01-01')
datelist2012 = pd.date_range(y_2012, periods=355) # from 2012-01-12 to 2012-12-31
datelist2013 = pd.date_range(y_2013, periods=365) # from 2013-01-01 to 2013-12-31
datelist2015 = pd.date_range(y_2015, periods=365) # from 2015-01-01 to 2015-12-31
datelist2016 = pd.date_range(y_2016, periods=351) # from 2016-01-01 to 2016-12-31 (leap year)
datelist2017 = pd.date_range(y_2017, periods=365) # from 2017-01-01 to 2017-12-31

# %%
datelist = [] # 2016
for date in datelist2016:
    d = str(date).split(" ")[0]
    d = d.replace("-", "")
    datelist.append(d)
print(len(datelist)) # 1827 days to crawl
# Out:
# 353

# %%
url_sample = "http://news.chosun.com/svc/list_in/list.html?indate="

urls=[]

for date in datelist:
    urls.append(url_sample+date)

# %%
class Article:
    title=""
    category=""
    paragraph=""

# %%
def text_writer(article, date):
    name = date + "_" + article.category + "_" + article.title
    txt = ""
    txt = txt + article.paragraph
    name = name.replace("/", " ")
    
    with open("./output/"+ name +".txt", "w") as text_file:
        text_file.write(txt)

def xml_writer(article, date):
    name = date + "_" + article.category + "_" + article.title
    name = name.replace("/", " ")
    title = E("title", article.title)
    category = E("category", article.category)
    paragraph = E("paragraph", article.paragraph)
    article_xml = E("article", category, title, paragraph)
    
    declaration = """<?xml version="1.0" encoding="utf-8"?>
    <!DOCTYPE articles SYSTEM "articles.dtd">
    """
    dec_byte = str.encode(declaration)
    with open("./output/"+ name +".xml", "wb") as f:
        f.write(dec_byte)
        f.write(ET.tostring(article_xml, xml_declaration=False, encoding="utf-8", pretty_print=True))
        
def article_extractor(article_urls, article_list, date):
    for article in article_urls:
        a = Article()
        browser.get(article)
        title_exist = len(browser.find_elements_by_id("news_title_text_id"))
        cat_exist = len(browser.find_elements_by_id("news_cat_trig_id"))
        par_exist = len(browser.find_elements_by_class_name("par"))
        if title_exist != 0 and cat_exist != 0 and par_exist != 0:
            a.title = browser.find_elements_by_id("news_title_text_id")[0].text
            a.category = browser.find_elements_by_id("news_cat_trig_id")[0].text
            a.paragraph = browser.find_elements_by_class_name("par")[0].text
            text_writer(a, date)
            xml_writer(a, date)

            #article_list.append(a)
            print(date, len(article_list),"번째 기사: '", a.title, "'완료")

def list_extractor(page_url, article_list, date):
    articles = browser.find_elements_by_class_name("list_item")
    article_urls=[]
    for article in articles:
        if len(article.find_elements_by_class_name("author")) != 0:
            author = article.find_elements_by_class_name("author")[0]
            if len(author.text) >= 5:
                if author.text[:5] == "스포츠조선": # Excluding Sports Articles
                    pass
                else:
                    article_urls.append(article.find_elements_by_tag_name("a")[0].get_attribute("href"))
            else:
                if len(author.text) >= 3:
                    if author.text[:5] == "뉴시스": # Excluding Newsis Articles
                        pass
                    else:
                        article_urls.append(article.find_elements_by_tag_name("a")[0].get_attribute("href"))
                else:
                    article_urls.append(article.find_elements_by_tag_name("a")[0].get_attribute("href"))
    article_extractor(article_urls, article_list, date)

def page_browser(url, article_list): # browsing pages of that date
    i=1 # page index
    while len(browser.find_elements_by_class_name("list_item")) >= 1:
        if i == 1:
            page = "&pn=" + str(i)
            date = url[-8:]
            page_url = url + page
            browser.get(page_url)
        list_extractor(page_url, article_list, date)
        i += 1
        page = "&pn=" + str(i)
        page_url = url + page
        browser.get(page_url)
        
def contemporary_chosun_crawler(urls):
    article_list=[]
    for url in urls:
        browser.get(url)
        page_browser(url, article_list)

# %%
browser = webdriver.Firefox()
contemporary_chosun_crawler(urls)
# Out:
# 20160114 0 번째 기사: ' 제주 관광 온 베트남인 46명 사라져…당국 수색중 '완료
# 20160114 0 번째 기사: ' '스폰서 제안' 타히티 지수, 고소인 자격으로 경찰 출석 '완료
# 20160114 0 번째 기사: ' '해리포터' 스네이프 교수역 앨런 릭먼 암으로 사망 '완료
# 20160114 0 번째 기사: ' [TV조선 단독] 유명 정신과 교수, 인턴 성추행 사건에 대학병원 '발칵' '완료
# 20160114 0 번째 기사: ' 윷놀이 도박에 빠진 가장, 가족들이 경찰에 신고 '완료
# 20160114 0 번째 기사: ' '청와대 방어' 레이더, 소형 무인기 탐지율 50%도 안돼 '완료
# 20160114 0 번째 기사: ' 中 정부, '투명인간' 1300만명 호적 등록하기로 '완료
# 20160114 0 번째 기사: ' [카드뉴스] 돈 좀 벌었다고 막 쓰고 다니는 그 남자 '완료
# 20160114 0 번째 기사: ' [카드뉴스] 돈 좀 벌었다고 막 쓰고 다니는 그 남자 '완료
# 20160114 0 번째 기사: ' 안대희 "당선 가능성 고려해 이번주에 출마지역 결정" '완료
# 20160114 0 번째 기사: ' [카드뉴스] 중국 예능, 이정도면 '복붙' 아닌가요? '완료
# 20160114 0 번째 기사: ' [카드뉴스] 중국 예능, 이정도면 '복붙' 아닌가요? '완료
# 20160114 0 번째 기사: ' 美공화, 오바마 北核 무대응에 "다른세상 살고있다" '완료
# 20160114 0 번째 기사: ' 美 복권 '파워볼' 당첨자 3명..1인당 3730억원 '완료
# 20160114 0 번째 기사: ' 스페인 女의원 의회서 母乳 수유 논란 '완료
# 20160114 0 번째 기사: ' 전공 무관한 취업, 연봉도 낮아 '완료
# 20160114 0 번째 기사: ' 자카르타 한복판서 폭탄테러…범인 14명, 경찰과 시가戰 '완료
# 20160114 0 번째 기사: ' 헐리우드 대표 女스타 5인의 '극한' 몸매 관리 비법은 '완료
# 20160114 0 번째 기사: ' IS "자카르타 테러 우리가 했다" 주장…인니 경찰 "파리 테러 모방한 것" '완료
# 20160114 0 번째 기사: ' "유명해지고 싶다"는 여덟살 시한부 소년의 꿈 위해 뭉친 네티즌들 '완료
# 20160114 0 번째 기사: ' 경기도, 통일한국 이끌 경기 북부 발전 마스터플랜 공개 '완료
# 20160114 0 번째 기사: ' 中 상하이 도심 한가운데 바람을 조종하는 무림 고수가 나타났다? '완료
# 20160114 0 번째 기사: ' 시외버스 세워놓고 사라진 美 버스기사, 2시간 추위에 떤 승객들이 회사에 항의하니 '완료
# 20160114 0 번째 기사: ' 10대 여친과 교제하려고 세 살 아들 살해한 비정한 美 아빠 '완료
# 20160114 0 번째 기사: ' [오늘의 운세] 1월 15일 금요일(음력 12월 6일 丙申) '완료
# 20160114 0 번째 기사: ' '대만 국기' 흔들어서? 대만 출신 걸그룹 멤버 쯔위, 中서 논란에 결국 활동 중단 '완료
# 20160114 0 번째 기사: ' 감사원 "메르스 사태, 초기대응 부실 등 총체적 난국이 피해 키워" '완료
# 20160114 0 번째 기사: ' 대법, 고용노동부 시정명령 거부' 전교조에 유죄 확정 '완료
# 20160114 0 번째 기사: ' 질병관리본부, 인플루엔자 유행주의보 발령 '완료
# 20160114 0 번째 기사: ' 엉뚱한 손님 노숙자로 착각해 식사 대접하려다 머쓱해진 英 여성 '완료
# 20160114 0 번째 기사: ' 중국,경기둔화 속 철광석·원유 사상 최대 수입 미스터리 '완료
# 20160114 0 번째 기사: ' 안철수 "더민주 김종인 영입, 야권 경쟁 바람직" '완료
# 20160114 0 번째 기사: ' [Video C] 3년만에 안방극장으로 돌아온 국민 여배우 김혜수 '완료
# 20160114 0 번째 기사: ' 김수남 검찰총장, 故 정주영 회장 거론하며 "현장에서 역발상으로 혁신하라" '완료
# 20160114 0 번째 기사: ' 글로벌 자금, 금·우량 회사채·엔화로 몰려...'안전자산 선호' '완료
# 20160114 0 번째 기사: ' 17억원짜리 유일한 국산 수퍼카, 전라남도 청사 1층에 주차된 이유는? '완료
# 20160114 0 번째 기사: ' 데일리NK "김정은 '모심조', 北서 '막강 파워'…2인자 황병서도 깔본다" '완료
# 20160114 0 번째 기사: ' 문재인 "선대위 안정되면 야권통합 위해 대표직 사퇴" '완료
# 20160114 0 번째 기사: ' "호주 캥거루 가족 사진은 '어미의 죽음'이 아니라 교미 시도 장면" '완료
# 20160114 0 번째 기사: ' 문재인, 김종인 영입으로 인재영입 '화룡점정' '완료
# 20160114 0 번째 기사: ' 檢, 성추행 혐의 이경실씨 남편에 징역 2년 구형 '완료
# 20160114 0 번째 기사: ' '건축계 노벨상' 프리츠커상 수상자로 칠레 아라베나 선정 '완료
# 20160114 0 번째 기사: ' [단독]타히티 지수에 '스폰서' 제안한 브로커 계정 추적해보니…일반 여성에게도 '고액 알바' 제안 '완료
# 20160114 0 번째 기사: ' G2 리스크 '2라운드'…세계 경제 흔들 '완료
# 20160114 0 번째 기사: ' 중학생이 만든 해킹프로그램으로 '좋아요' 많은 페이스북 20여개 빼앗은 일당 '완료
# 20160114 0 번째 기사: ' 김종인 "朴대통령, 남의 의견 중요치 않다고 판단" 비판 '완료
# 20160114 0 번째 기사: ' '고의파산' 논란 개그맨 김준호, 배임·업무방해 혐의 벗었다 '완료
# 20160114 0 번째 기사: ' 둘이 합쳐 330kg 부부, 결혼사진에 충격 받아 153kg 감량 성공 '완료
# 20160114 0 번째 기사: ' 强달러의 역습⋯미국 떠나는 글로벌 기업들 '완료
# 20160114 0 번째 기사: ' 억대 사기 '테크노 골리앗' 최홍만에 징역 1년에 집유 2년 선고 '완료
# 20160114 0 번째 기사: ' 이준석, 더민주 김종인 영입에 "새누리 출혈이 다른 당에는 헌혈" '완료
# 20160114 0 번째 기사: ' 장윤정母 육흥복씨, 이복동생과 장윤정 팬카페 운영자 명예훼손으로 고소 '완료
# 20160114 0 번째 기사: ' 미국 어린이집에선 아기 학대하면, 최고 41년형 징역 '완료
# 20160114 0 번째 기사: ' 오바마·푸틴, "북한 핵실험에 혹독한 제재" 합의 '완료
# 20160114 0 번째 기사: ' 조동원·손혜원·이상민…정치권 홍보 전문가 '3당 3색' '완료
# 20160114 0 번째 기사: ' [속보] 더민주, 朴 대통령 경제멘토 김종인 전 의원 영입 '완료
# 20160114 0 번째 기사: ' 美 "한일과 미사일방어(MD) 체계 강화 방안 논의 중" '완료
# 20160114 0 번째 기사: ' 1조9000원 걸린 美 로또 '파워볼' 당첨자 나왔다 '완료
# 20160114 0 번째 기사: ' 드디어 나온 1조8000억의 주인공? 美 '파워볼' 당첨 인증샷 화제 '완료
# 20160114 0 번째 기사: ' 국민의당 한상진 "이승만 전 대통령은 國父" '완료
# 20160114 0 번째 기사: ' 오전엔 "위안부는 직업위안부' 오후엔 "오해 불러 철회"…위안부 합의 17일 만에 현역 자민당 의원 망언 '완료
# 20160114 0 번째 기사: ' '스타워즈' 패러디한 환경부 공익광고, 서울영상광고제 대상 '완료
# 20160114 0 번째 기사: ' 멸종된 줄 알았던 고대 바다악어 화석, 사하라사막 흙 속에서 발견 '완료
# 20160114 0 번째 기사: ' 北, 14일에도 대남 전단 살포…"어제 수만장 수거" '완료
# 20160114 0 번째 기사: ' 이 캥거루 가족이 어미의 죽음을 받아들이는 법 '완료
# 20160114 0 번째 기사: ' 음저협, CGV상대 '영화음악 무단사용' 손해배상 청구 최종 패소 '완료
# 20160114 0 번째 기사: ' 차기 대선주자 지지도 문재인 1위…안철수·김무성 순 '완료
# 20160114 0 번째 기사: ' 부산고법 "현대중공업 명절상여금 통상임금 아니다"...법원 '고정성', '신의칙' 오락가락 '완료
# 20160114 0 번째 기사: ' 예비역 육군 소장 하정열, 더민주 입당 '완료
# 20160114 0 번째 기사: ' 까치도 흡연을? 英 맨체스터서 찍힌 까치 사진에 트위터 '시끌' '완료
# 20160114 0 번째 기사: ' '아사 위기' 신생아 살리기 위해 모유 수유한 콜롬비아 여경 '완료
# 20160114 0 번째 기사: ' 20대 절반 이상 욕설·비속어 사용…이유는 '습관적으로' '완료
# 20160114 0 번째 기사: ' 브라질서 131세 남성 확인돼... 세계 최장수 기록 갈릴까 '완료
# 20160114 0 번째 기사: ' 朴대통령 "코리아 블랙 프라이데이, 정례화해야" '완료
# 20160114 0 번째 기사: ' 8층 건물 옥상서 행인에 돌 던진 '분노 조절 장애' 40대 남성 검거 '완료
# 20160114 0 번째 기사: ' 더민주 김승남 탈당..더민주 111석으로 줄어 '완료
# 20160114 0 번째 기사: ' 法, '워터파크 몰카범'에 중형선고…징역 각각 4년 6월, 3년 6월 '완료
# 20160114 0 번째 기사: ' 문재인 "박 대통령, 정치적 중립 지켜달라" '완료
# 20160114 0 번째 기사: ' 이종걸 "朴 대통령은 '탓통령' '떼통령'" 비판 '완료
# 20160114 0 번째 기사: ' 높이 12m 절벽에서 다이빙 하려다 추락한 여성..결과는 '완료
# 20160114 0 번째 기사: ' 문재인 "朴대통령 위안부 협상 자화자찬에 얼굴 화끈…부끄러워" '완료
# 20160114 0 번째 기사: ' 새누리·더민주, 국민의당 '총선 연기 주장'에 "무책임하다" '완료
# 20160114 0 번째 기사: ' 늦게 출동한 경찰관에 '아이, X발' 욕설…대법 "모욕죄 아니다" '완료
# 20160114 0 번째 기사: ' [전관예우 백약무효]㉒ ‘재판부 재배당’ 전관예우 근절 효과...지방법원은 “현실적으로 아직” '완료
# 20160114 0 번째 기사: ' 서청원, 아베 만나 "위안부 협상 왜곡 보도 관리해달라" 朴 메시지 전달 '완료
# 20160114 0 번째 기사: ' 與 김영우 "정부·여당, 적극적으로 사드 배치 검토해야" '완료
# 20160114 0 번째 기사: ' 남다른 '뒷태·옆태' 뽐내는 치어리더 '완료
# 20160114 0 번째 기사: ' [속보]이부진 호텔신라 사장, 17년 만에 이혼 '완료
# 20160114 0 번째 기사: ' [특수단 출범]② '거미손' 주영환 1팀장, "끝을 보는 특수통" '완료
# 20160114 0 번째 기사: ' "'처음처럼' 비방 하이트진로 33억 배상" '완료
# 20160114 0 번째 기사: ' 靑 "사드, 朴대통령 발언 그대로 이해해 달라" '완료
# 20160114 0 번째 기사: ' 신태용호 우즈벡 상대로 2-1승리 '완료
# 20160114 0 번째 기사: ' [유라시안 브리핑] 인니·방글라데시 기준금리 인하 '완료
# 20160114 0 번째 기사: ' 한국 조 1위로 2018 월드컵 최종 예선 진출 확정 '완료
# 20160114 0 번째 기사: ' '경기침체 및 성장 둔화'와 '노후 준비' 한국 성인 최고 걱정거리 '완료
# 20160114 0 번째 기사: ' "혼자서도 밥 잘 먹어요" '완료
# 20160114 0 번째 기사: ' 장(腸)이 편해야 몸이 편하다 '완료
# 20160114 0 번째 기사: ' 이부진 호텔신라 사장 이혼 소송, 오늘 선고 '완료
# 20160114 0 번째 기사: ' 연준 베이지북 "美 경제 완만하게 확장세 지속…임금 상승률은 미미" '완료
# 20160114 0 번째 기사: ' [양상훈 칼럼] 미국도 '북핵 있는 현상 유지'로 가고 있다 '완료
# 20160114 0 번째 기사: ' 위안貨 곤두박질에도… 中 당국이 느긋한 까닭 '완료
# 20160114 0 번째 기사: ' 중국 무역액, 6년만에 감소 '완료
# 20160114 0 번째 기사: ' 경기도 학부모·유치원 "누리예산 전액 편성하라" 집단항의 '완료
# 20160114 0 번째 기사: ' "누리 과정, 교육감들이 아이들 볼모로 정치적 공격" '완료
# 20160114 0 번째 기사: ' [리빙포인트] 커피자국 지우는 방법 '완료
# 20160114 0 번째 기사: ' "덕선이 남편은 ○○" 응팔 결말 누설 대란 '완료
# 20160114 0 번째 기사: ' [TV조선 ch19] 좁혀지지 않는 모자 갈등 '완료
# 20160114 0 번째 기사: ' 日 국민 그룹 'SMAP' 25년 만에 해체 위기 '완료
# 20160114 0 번째 기사: ' [삼시세평(三視世評)] 그 나물에 그 밥인데… 곱씹으니 또 맛있네 '완료
# 20160114 0 번째 기사: ' 323일만에… 인삼공사 심봤다 '완료
# 20160114 0 번째 기사: ' 에러 없는 에밋 '완료
# 20160114 0 번째 기사: ' 암울한 중국… 일본은 기분 좋은 출발 '완료
# 20160114 0 번째 기사: ' "돼지란 말 안들어야죠" 호랑이 잡는 겨울시험 '완료
# 20160114 0 번째 기사: ' [제20회 LG배 조선일보 기왕전] 노련미의 승리 '완료
# 20160114 0 번째 기사: ' 메시, 혹시 넌 아니지? '완료
# 20160114 0 번째 기사: ' 평창의 기도 통했나… 영하 16도까지 뚝 '완료
# 20160114 0 번째 기사: ' [김대식의 브레인 스토리] [170] 망각의 안개에 빠진 대한민국? '완료
# 20160114 0 번째 기사: ' [TV조선 칼럼] 카메라가 세상을 바꾼다 '완료
# 20160114 0 번째 기사: ' [윤희영의 News English] 호텔의 화려함에 감춰진 비밀들 '완료
# 20160114 0 번째 기사: ' [김민철의 꽃이야기] 모르는게 더 좋았을 갈매나무와 시인 白石의 삶 '완료
# 20160114 0 번째 기사: ' [발언대] 北 SLBM 위협 대비, 일본만큼은 해야 '완료
# 20160114 0 번째 기사: ' [발언대] 국회선진화법, 수정 불가피하다 '완료
# 20160114 0 번째 기사: ' [일사일언] 면접에 대한 예의 '완료
# 20160114 0 번째 기사: ' [동서남북] 증시 폭락하는데 펀드 정리 나선 정부 '완료
# 20160114 0 번째 기사: ' [만물상] 정치인의 편지 '완료
# 20160114 0 번째 기사: ' [열린 포럼] 중앙에 손 벌리게 하는 지방자치 '완료
# 20160114 0 번째 기사: ' 세 번의 '떡메'소리… 세 번의 비극을 알리다 '완료
# 20160114 0 번째 기사: ' "수행 꿈꾸는 전문직 은퇴자, 출가의 길 열어드릴게요" '완료
# 20160114 0 번째 기사: ' "110년前 보부상 조직, 양반과 日상인까지 받아들여" '완료
# 20160114 0 번째 기사: ' 수유할 때, 잠재울 때도… 육아엔 '행동 요령' 있습니다 '완료
# 20160114 0 번째 기사: ' 美 하원 '北과 거래하는 제3국 기업 제재' 행정부에 맡겨 '완료
# 20160114 0 번째 기사: ' 의적 이미지 꿈꾼 '마약왕' 구스만, 이름 상표등록 시도 '완료
