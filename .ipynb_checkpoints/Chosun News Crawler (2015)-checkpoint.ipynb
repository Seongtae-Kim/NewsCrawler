# %%
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from collections import defaultdict
import pandas as pd
from datetime import datetime, date
from lxml import etree as ET
from lxml.builder import E

# %% [markdown]
# # Contemporary Chosun Crawler
# 조선일보 2012, 2013, 2015, 2016, 2017년도 기사를 크롤링합니다.

# %%
y_2012 = date.fromisoformat('2012-01-12')
y_2013 = date.fromisoformat('2013-01-01')
y_2015 = date.fromisoformat('2015-01-13')
y_2016 = date.fromisoformat('2016-01-01')
y_2017 = date.fromisoformat('2017-01-01')
datelist2012 = pd.date_range(y_2012, periods=355) # from 2012-01-12 to 2012-12-31
datelist2013 = pd.date_range(y_2013, periods=365) # from 2013-01-01 to 2013-12-31
datelist2015 = pd.date_range(y_2015, periods=353) # from 2015-01-01 to 2015-12-31
datelist2016 = pd.date_range(y_2016, periods=366) # from 2016-01-01 to 2016-12-31 (leap year)
datelist2017 = pd.date_range(y_2017, periods=365) # from 2017-01-01 to 2017-12-31

# %%
datelist = [] # 2015
for date in datelist2015:
    d = str(date).split(" ")[0]
    d = d.replace("-", "")
    datelist.append(d)
print(len(datelist)) # 1827 days to crawl
# Out:
# 355

# %%
url_sample = "http://news.chosun.com/svc/list_in/list.html?indate="

urls=[]

for date in datelist:
    urls.append(url_sample+date)

# %%
class Article:
    title=""
    category=""
    paragraph=""

# %%
def text_writer(article, date):
    name = date + "_" + article.category + "_" + article.title
    txt = ""
    txt = txt + article.paragraph
    name = name.replace("/", " ")
    
    with open("./output/"+ name +".txt", "w") as text_file:
        text_file.write(txt)

def xml_writer(article, date):
    name = date + "_" + article.category + "_" + article.title
    name = name.replace("/", " ")
    title = E("title", article.title)
    category = E("category", article.category)
    paragraph = E("paragraph", article.paragraph)
    article_xml = E("article", category, title, paragraph)
    
    declaration = """<?xml version="1.0" encoding="utf-8"?>
    <!DOCTYPE articles SYSTEM "articles.dtd">
    """
    dec_byte = str.encode(declaration)
    with open("./output/"+ name +".xml", "wb") as f:
        f.write(dec_byte)
        f.write(ET.tostring(article_xml, xml_declaration=False, encoding="utf-8", pretty_print=True))
        
def article_extractor(article_urls, article_list, date):
    for article in article_urls:
        a = Article()
        browser.get(article)
        title_exist = len(browser.find_elements_by_id("news_title_text_id"))
        cat_exist = len(browser.find_elements_by_id("news_cat_trig_id"))
        par_exist = len(browser.find_elements_by_class_name("par"))
        if title_exist != 0 and cat_exist != 0 and par_exist != 0:
            a.title = browser.find_elements_by_id("news_title_text_id")[0].text
            a.category = browser.find_elements_by_id("news_cat_trig_id")[0].text
            a.paragraph = browser.find_elements_by_class_name("par")[0].text
            text_writer(a, date)
            xml_writer(a, date)

            #article_list.append(a)
            print(date, len(article_list),"번째 기사: '", a.title, "'완료")

def list_extractor(page_url, article_list, date):
    articles = browser.find_elements_by_class_name("list_item")
    article_urls=[]
    for article in articles:
        if len(article.find_elements_by_class_name("author")) != 0:
            author = article.find_elements_by_class_name("author")[0]
            if len(author.text) >= 5:
                if author.text[:5] == "스포츠조선": # Excluding Sports Articles
                    pass
                else:
                    article_urls.append(article.find_elements_by_tag_name("a")[0].get_attribute("href"))
            else:
                if len(author.text) >= 3:
                    if author.text[:5] == "뉴시스": # Excluding Newsis Articles
                        pass
                    else:
                        article_urls.append(article.find_elements_by_tag_name("a")[0].get_attribute("href"))
                else:
                    article_urls.append(article.find_elements_by_tag_name("a")[0].get_attribute("href"))
    article_extractor(article_urls, article_list, date)

def page_browser(url, article_list): # browsing pages of that date
    i=1 # page index
    while len(browser.find_elements_by_class_name("list_item")) >= 1:
        if i == 1:
            page = "&pn=" + str(i)
            date = url[-8:]
            page_url = url + page
            browser.get(page_url)
        list_extractor(page_url, article_list, date)
        i += 1
        page = "&pn=" + str(i)
        page_url = url + page
        browser.get(page_url)
        
def contemporary_chosun_crawler(urls):
    article_list=[]
    for url in urls:
        browser.get(url)
        page_browser(url, article_list)

# %%
browser = webdriver.Firefox()
contemporary_chosun_crawler(urls)
# Out:
# 20150111 0 번째 기사: ' 파리 테러범, 테러 전 'IS 충성 맹세' 동영상 유포 '완료
# 20150111 0 번째 기사: ' [TV조선 단독]"김영한, 항명 전 김 실장과 사퇴 논의" '완료
# 20150111 0 번째 기사: ' [TV조선 단독] "태양절 모른다" 신은미 거짓말 거짓말 거짓말 '완료
# 20150111 0 번째 기사: ' [TV조선 단독] 황선 "北, 계급 떠나 행복 추구"…방북 다이어리에 이적 표현 '추가 확인' '완료
# 20150111 0 번째 기사: ' 테러 경계령 속 파리에 온 세계 40여개국 정상, 시민과 함께 테러 반대 행진 '완료
# 20150111 0 번째 기사: ' 홍콩 최대 부호 리카싱의 청쿵그룹, 시진핑 피해 홍콩 떠나나 '완료
# 20150111 0 번째 기사: ' 김영란法 2월 국회로…크루즈법·마리나법 통과될 듯(종합) '완료
# 20150111 0 번째 기사: ' 홍콩 최대 부호 리카싱 "홍콩 떠난다"…시진핑 反부패 한파 몰아치나 '완료
# 20150111 0 번째 기사: ' 외교부 당국자, 北의 '한미훈련 중단시 핵실험 중단' 제안에 "연계될 사안 아냐" '완료
# 20150111 0 번째 기사: ' 건물간격 규제완화·스프링클러 미비가 의정부 화재 키워 '완료
# 20150111 0 번째 기사: ' [오늘의 운세] 1월 12일 월요일(음력 11월 22일 戊子) '완료
# 20150111 0 번째 기사: ' [프리미엄] 밥 사 먹인다는 엄마의 죄책감, 재료로 덜어준 '김밥집' '완료
# 20150111 0 번째 기사: ' 파리연쇄 테러 일당 중 유일 생존자, 터키 거쳐 시리아 입국說 '완료
# 20150111 0 번째 기사: ' [프리미엄] 6초 내쉬고 3초 들이쉬고 호흡만으로 두통 없앤다 '완료
# 20150111 0 번째 기사: ' [프리미엄] 세종대왕 때 인재가 많이 나올 수 있었던 건 '싸움' 때문 '완료
# 20150111 0 번째 기사: ' 추락 에어아시아기 탑승 한국인 부부 시신 확인돼 '완료
# 20150111 0 번째 기사: ' 低유가로 예산 압박 시달리는 GCC…과세 방안 고민 중 '완료
# 20150111 0 번째 기사: ' "北 탈영병의 중국인 살해 이후 중국군 2000명 추가로 국경배치" '완료
# 20150111 0 번째 기사: ' 김영란法 소위 통과, 어처구니 없는 막전막후 '완료
# 20150111 0 번째 기사: ' ‘개 소송 다툼’ 벌인 앙숙 홍준표와 안상수, 또 충돌 '완료
# 20150111 0 번째 기사: ' "北, 스키장 건설에 軍동원했다가 사고로 병사 10여명 숨져" '완료
# 20150111 0 번째 기사: ' 法 "현금영수증 미발급에 50% 과태료는 지나친 처벌" 위헌 제청 '완료
# 20150111 0 번째 기사: ' "북한, 병사들 체력저하로 개인 전투장구류 경량화 착수" '완료
# 20150111 0 번째 기사: ' 천정배, "당장 탈당 생각 없어…좀 더 온건한 진보 세력화 희망" '완료
# 20150111 0 번째 기사: ' 정동영 탈당에 문재인 "안타깝다", 이인영 "명백한 잘못" '완료
# 20150111 0 번째 기사: ' [단독]서초동 세 모녀 살해 가장, 수면제 먹인 후 범행 확인 '완료
# 20150111 0 번째 기사: ' "술집 나가는 X은 내 강의서 나가라"…법원, "막말 교수 파면은 정당" '완료
# 20150111 0 번째 기사: ' 신은미 도착한 LA공항서 교민끼리 충돌 '완료
# 20150111 0 번째 기사: ' ECB 5000억유로 국채매입 논의…22일 정례회의 앞두고 QE 저울질 '완료
# 20150111 0 번째 기사: ' 조현아 전 사장, 혹떼주려다 혹 붙여준 국토부 '완료
# 20150111 0 번째 기사: ' [단독]광주과학기술원, 개인 블로거 사진 무단 도용했다 삭제 소동 '완료
# 20150111 0 번째 기사: ' "술집 나가는 X은 내 강의서 나가라"…법원, "막말 교수 파면은 정당" '완료
# 20150111 0 번째 기사: ' 정동영은 누구?..대선후보와 통일부장관 지낸 야권 핵심인사 '완료
# 20150111 0 번째 기사: ' [주간조선]피츠버그가 강정호에 500만달러 베팅한 이유 '완료
# 20150111 0 번째 기사: ' 애플, 加·유럽 앱 가격 인상…"환율·부가세율 상승 반영" '완료
# 20150111 0 번째 기사: ' 대법 "회의 참석 안 한 사외이사 분식회계 책임있다" '완료
# 20150111 0 번째 기사: ' [TV조선]美 미시간주서 150중 추돌사고…폭죽 터지면서 불 옮겨붙어 '완료
# 20150111 0 번째 기사: ' [TV조선]美 "북한 제안 거부…핵실험 언급은 암묵적 위협" '완료
# 20150111 0 번째 기사: ' 새정치연합, 정동영 탈당에 "어머니의 마음으로 기다리겠다" '완료
# 20150111 0 번째 기사: ' 정동영 탈당에 비상등 켜진 야당…4월 보궐선거 어떻게 하나 '완료
# 20150111 0 번째 기사: ' 日 닌텐도 브라질 영업 중단 '완료
# 20150111 0 번째 기사: ' 朴대통령, 신년 기자회견 3대 관전포인트 '완료
# 20150111 0 번째 기사: ' 日언론 "신동주 전 일본 롯데홀딩스 부회장, 후계 구도 아닌 전문경영인과의 대립이 해임 원인" '완료
# 20150111 0 번째 기사: ' 정동영, 새정치연합 탈당… '국민모임' 신당 합류 '완료
# 20150111 0 번째 기사: ' [TV조선] '전동 드릴'로 위협해 초등생 성추행한 교직원들 '완료
# 20150111 0 번째 기사: ' [유선의 TV조선 기자의 동분서주]김학의 전 차관을 성접대했다는 여성이 직접 털어놓은 이야기 '완료
# 20150111 0 번째 기사: ' 피치, 러시아 신용등급 BBB-로 강등…투기등급 직전 '완료
# 20150111 0 번째 기사: ' [여성조선] 코리아나 이용규 엄친딸 이래나의 생생 예일대 이야기 '완료
# 20150111 0 번째 기사: ' [여성조선] 말기 암 완치하고 다시 선 가수 조승구 '완료
# 20150111 0 번째 기사: ' 소득수준 양극화에 따라 만성질환 양극화도 늘어…가난할 수록 男 골관절염·女 비만 확률 ↑ '완료
# 20150111 0 번째 기사: ' 4대 로펌 변호사의 여가 사용설명서 '완료
# 20150112 0 번째 기사: ' 검찰, 한솔그룹 3세 병역법 위반 혐의 수사 착수 '완료
# 20150112 0 번째 기사: ' 제48대 대한변협 회장에 하창우 변호사 당선 '완료
# 20150112 0 번째 기사: ' [프리미엄] "맏아들을 구하자" 효성 조석래 회장의 눈물겨운 '장남 사랑' '완료
# 20150112 0 번째 기사: ' 남경필 지사, '빅데이터' 통해 도정 혁신 추구 '완료
# 20150112 0 번째 기사: ' [프리미엄] 어눌한 말주변에도 정몽구 회장, 대본 없이 이례적 '즉흥 신년사' '완료
# 20150112 0 번째 기사: ' [프리미엄] 정력가 되려면 겨울철 이 음식 집중공략 해라 '완료
# 20150112 0 번째 기사: ' 김주하 MBC 앵커 결혼 11년만에 이혼 '완료
# 20150112 0 번째 기사: ' [오늘의 운세] 1월 13일 화요일(음력 11월 23일 己丑) '완료
# 20150112 0 번째 기사: ' 김주하 MBC 앵커 결혼 11년만에 이혼 '완료
# 20150112 0 번째 기사: ' 신용정보보호법, 국회 정무위 통과 '완료
# 20150112 0 번째 기사: ' 세월호 배·보상 특별법 국회 본회의 통과… 참사 271일만 '완료
# 20150112 0 번째 기사: ' 불법 정치자금 수수 박상은 새누리당 의원 집행유예 선고 '완료
# 20150112 0 번째 기사: ' 故 신해철씨 수술한 병원, 명칭 바꿔 영업 시작해 논란 '완료
# 20150112 0 번째 기사: ' 美CNN "중국이 가장 잘하는 10가지"…건물 빨리 짓기, 베끼기 '완료
# 20150112 0 번째 기사: ' 불법 정치자금 수수 박상은 새누리당 의원 집행유예 선고 '완료
# 20150112 0 번째 기사: ' 이석기 전 의원을 '양심수'처럼 보이게 만드는 구명 광고들 '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령, 거친화법-과잉제스처…"정국주도 메시지" '완료
# 20150112 0 번째 기사: ' 故신해철씨 수술 강모 원장, 병원이름 바꾸고 '진료中' '완료
# 20150112 0 번째 기사: ' 프랑스 反 테러 시위 역대 최대 규모 370만명 참가…40여개국 정상급 지도자도 참석 '완료
# 20150112 0 번째 기사: ' [신년 회견] '정치적 위기' 朴대통령…'경제'로 반전 노린다 '완료
# 20150112 0 번째 기사: ' 크로아티아 첫 여성 대통령 선출 '완료
# 20150112 0 번째 기사: ' "한번 신뢰하면 끝까지 간다"…변함없는 朴대통령의 용인술 '완료
# 20150112 0 번째 기사: ' [홍성추의 재벌가 인사이드(29)]어눌하기로 유명한 정몽구 회장이 대본없이 15분간 즉흥 연설한 이유 '완료
# 20150112 0 번째 기사: ' [프리미엄] 올 겨울, 에볼라보다 더 무서운 바이러스 몰려온다 '완료
# 20150112 0 번째 기사: ' [조현아 공판]② 檢, 항공기 안전운항저해·폭행 입증 자신 '완료
# 20150112 0 번째 기사: ' [일문일답] 朴대통령 "터무니없는 논란, 우리 사회 건전치 않아" '완료
# 20150112 0 번째 기사: ' 요즘 드라마, 절대 빠질 수 없어! 김 서방 보다 많은 재벌 2세 '완료
# 20150112 0 번째 기사: ' '보이후드' 골든글로브 3관왕 영예…감독상,여우조연상,드라마 영화부문 작품상 '완료
# 20150112 0 번째 기사: ' 안철수 "야당 전당대회 혁신 안 보이면 전면에 나서 비판하겠다" '완료
# 20150112 0 번째 기사: ' [줌인] 해외 사업 옥석 가리는 英·美 은행들…잇단 구조조정 '완료
# 20150112 0 번째 기사: ' 朴 대통령이 빨강 재킷 입고 나온 까닭은? '완료
# 20150112 0 번째 기사: ' '300만원 투자해 100억 벌었다'는 투자자문사 대표, 알고보니… '완료
# 20150112 0 번째 기사: ' 일본, 팔레스타인과 아시안컵 1차전 격돌…혼다·카가와 '총출동' '완료
# 20150112 0 번째 기사: ' 파주 LG디스플레이 공장에서 질소 누출… 2명 사망 4명 부상 '완료
# 20150112 0 번째 기사: ' 친노 안희정 지사, 박정희 대통령 이어 박근혜 대통령도 긍정 평가 '완료
# 20150112 0 번째 기사: ' [조선 Video] 중년 주부의 배와 팔뚝은 날씬하게, 엉덩이는 탄력있게 만드는 간단 운동법 '완료
# 20150112 0 번째 기사: ' [알립니다] TV조선 경력기자 모집 공고 '완료
# 20150112 0 번째 기사: ' 벤츠 CEO, "5년 안에 글로벌 고급차 시장 1위 되찾겠다" '완료
# 20150112 0 번째 기사: ' 고용노동부 "이상봉씨 디자인실, 위메프에 근로감독 할 것" '완료
# 20150112 0 번째 기사: ' 김영란법 정무위 통과…법사위 상정은 '유보'(종합) '완료
# 20150112 0 번째 기사: ' [프리미엄] 손바닥만 한 가게에서 월 6천만 원씩 매상 올리는 청년들 '완료
# 20150112 0 번째 기사: ' '서초구 세 母女 살해사건' 피의자 강씨 "와인에 수면제 넣어 아내에게 마시게 했다" '완료
# 20150112 0 번째 기사: ' 박 대통령 회견에 野 "고집불통의 오기만 보여", 與 "고뇌에 찬 자성" '완료
# 20150112 0 번째 기사: ' [단독]오세훈, 4월 보궐선거 출마 질문에 "생각 없다. 당분간 현실정치와 거리 둘 것" '완료
# 20150112 0 번째 기사: ' 추락한 에어아시아기 블랙박스 회수…상태에 따라 복원 시간 2일~2주 걸려 '완료
# 20150112 0 번째 기사: ' [신년 회견] 與 "新국가 청사진 제시" 野 "고집불통 재확인" '완료
# 20150112 0 번째 기사: ' [여성조선] 꿈꾸는 엄마가 기적을 만든다 '완료
# 20150112 0 번째 기사: ' [신년 회견] 비서 3인방 신임 공개천명…"교체할 이유 없어" '완료
# 20150112 0 번째 기사: ' 조응천·박관천 겨냥한 박 대통령, "개인적 영리위해 이간질" '완료
# 20150112 0 번째 기사: ' 학생운동 시위대 쇠파이프에 고환 맞은 전경, 23년만에 국가유공자 인정 될 듯 '완료
# 20150112 0 번째 기사: ' [19대 국회 경제법안 성향]① 기획재정위, 성장보다 분배 우선 '완료
# 20150112 0 번째 기사: ' 朴 대통령 "인사 지역 편중, 전체적으로 다시 검토해보겠다" '완료
# 20150112 0 번째 기사: ' 박 대통령, 장관들에게 "대면보고 늘리는 게 정말 필요하다고 생각해요?" 농담 '완료
# 20150112 0 번째 기사: ' 朴 대통령, 친박 만찬 질문에 "친박이라는 말 언제 떼어낼지…" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "제 소명, 경제부흥·평화통일 기반 닦는 것" '완료
# 20150112 0 번째 기사: ' 박 대통령 "국보법, 우리나라 안전 지키기 위한 최소한의 법" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "北美관계 안 좋아도 南北대화 멈출 필요 없어" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "부처 국장, 靑 적격성 검증서 바뀔 수 있어" '완료
# 20150112 0 번째 기사: ' 중국 항공기 이륙 직전 승객이 비상탈출구 열어 긴급 회항… "신선한 공기 마시고 싶어서" '완료
# 20150112 0 번째 기사: ' '김영란법' 정무위 전체회의 통과…법사위 상정은 연기(1보) '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "국가보안법, 우리 안전 지키기 위한 법" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "韓日정상회담 위해선 日 자세 변화 있어야" '완료
# 20150112 0 번째 기사: ' [푸드테라피스트 김연수의 음식으로 병치료 하기(22)] 최고 정력가 되려면 겨울철에 이걸 집중적으로 먹어라 '완료
# 20150112 0 번째 기사: ' 박 대통령 "개헌 논의로 경제 골든타임 놓치면 그 피해는 국민에게 돌아가" '완료
# 20150112 0 번째 기사: ' 朴 대통령 "사학·군인 연금 개혁 잘못 알려져…생각 안 하고 있다" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "사학·군인연금 개혁 지금 추진 안해…추후의 일" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "비정규직, 불합리한 임금차별 없어져야" '완료
# 20150112 0 번째 기사: ' 박 대통령 "내수 개선 위해서는 부동산 시장 회복돼야" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "올해 3.8% 성장률 이룰 수 있어" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "디플레이션 아냐…올해 재정 조기 집행" '완료
# 20150112 0 번째 기사: ' '셀피(selfie)' 즐기면 인격장애 가능성 높다? '완료
# 20150112 0 번째 기사: ' 朴 대통령, 기업인 가석방에 대해 "기업인이라고 역차별 받아서도 안돼" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "기업인 가석방, 기존 입장과 변화없어" 원론적 입장 표명 '완료
# 20150112 0 번째 기사: ' 김선형 '라틀리프, 내가 MVP 받아서 미안해' '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "北, 5·24조치 요구 전에 남북대화 응해야" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "비핵화 문제 해결 없이 평화통일 얘기 할 수 없어" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "남북정상회담 할 수 있어…전제 조건 없다" '완료
# 20150112 0 번째 기사: ' 영화 '국제시장', 잊어서는 안될 그 때 그 사건 ④ 1983년 이산가족찾기 '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "정윤회, 실세는 커녕 국정과 관계 없어" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "문건 파동, 특검 사안 아냐…의혹만 갖고 특검할 수 없어" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "김기춘·세 비서관 교체 이유 없어" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "김기춘, 당면 현안 수습 후 거취 결정" '완료
# 20150112 0 번째 기사: ' 박 대통령 "경제혁신 3개년 계획 성공 이뤄낼 것" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "항명파동이라 생각 안해…국회에 나갔어야" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "靑 조직개편, 주요 부문에 특보단 구성" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "문건파동, 檢 수사 결과 허위로 밝혀져" '완료
# 20150112 0 번째 기사: ' 박 대통령 "청와대도 새롭게 조직개편을 할 것" '완료
# 20150112 0 번째 기사: ' [신년 회견] 2015 신년 기자회견문 전문 '완료
# 20150112 0 번째 기사: ' 박근혜 대통령의 신년회견 모두발언 전문 '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "靑 새롭게 조직개편하고 국민과 소통할 것" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "올해 남북 자유왕래, 유라시아 향해 나가길 희망" '완료
# 20150112 0 번째 기사: ' 박 대통령 "남북 정상회담 할 수 있다…설 전후해서 이산가족 상봉하자" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "설 전후로 이산가족 상봉 이뤄질 수 있길 기대" '완료
# 20150112 0 번째 기사: ' 37년간 담배 피우다 금연 선언한 문형표 복지부 장관, 금단현상은? '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "민간 장기임대주택 공급 늘려 주거비 낮출 것" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "내수 개선 위해서는 부동산시장 회복돼야" '완료
# 20150112 0 번째 기사: ' 靑 기자단, 朴 대통령에게 질문지 미리 안줘 '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "고질적 규제, 내수부진·저성장 근본원인" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "농업, FTA 발판삼아 수출산업으로 키울 것" '완료
# 20150112 0 번째 기사: ' [프리미엄] 박태준에게 "뭐든 배워오면 국가를 위해 쓰일 날이 온다"고 했던 박정희 '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "제조업 혁신 3.0 전략 본격추진…젊은 인재 모이게 할 것" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "창조경제혁신센터, 전국에 열어 원스톱 지원체계 갖출 것" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "소득연계형 반값등록금 올해 완성" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "금융규제, 전례 없는 수준으로 혁파해야" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "노사, 3월까지 노동 구조개혁안 도출해달라" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "여야, 공무원 정년연장 등 사기진작책 보완" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "공무원연금, 4월까지 처리해달라…반드시 개혁해야" '완료
# 20150112 0 번째 기사: ' 박 대통령, "문건 파동 송구…세 비서관 교체 이유 없어" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "공공기관 중복기능 통폐합" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "공직 기강 바로잡겠다" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "공직자, 개인 영달 위해 기강 무너뜨린 일 용서할 수 없어" '완료
# 20150112 0 번째 기사: ' [신년 회견] 朴대통령 "문건 파동, 국민께 허탈함 드려 송구스럽다" '완료
# 20150112 0 번째 기사: ' 英 제약사 샤이어, 美 NPS 5조6000억원에 인수 '완료
# 20150112 0 번째 기사: ' 주호영 "공무원연금개혁, 대타협기구서 안되면 국회서 되게 할것" '완료
# 20150112 0 번째 기사: ' [뉴스 7] 中 언론 "성형 수술 악몽"…한국 원정 수술 위험성 지적 '완료
# 20150112 0 번째 기사: ' 시티그룹·골드만삭스 '그렉시트' 대비 스트레스 테스트 실시 '완료
# 20150112 0 번째 기사: ' [프리미엄] [별별다방] 40대 男, 아내의 외도를 덮고 재결합을 선택했지만… '완료
# 20150112 0 번째 기사: ' 박상학 자유북한운동연합 대표 "'인터뷰'DVD·USB 오는 20일 시범살포" '완료
# 20150112 0 번째 기사: ' 서울시 "애니메이션 라바로 꾸민 지하철 7호선도 운행" '완료
# 20150112 0 번째 기사: ' [뉴스 7] 황선, 북한 김정일 일화 책에도 등장 '완료
# 20150112 0 번째 기사: ' '샤를리 에브도'만평 전재한 독일 언론사에 방화 추정 화재…인명피해는 없어 '완료
# 20150112 0 번째 기사: ' [조호진 기자의 세상만사]신격호 회장 딸 신영자 이사장, 롯데 계열사 3곳에 사장 직함 걸어 놓고 35억원 연봉 받아 '완료
# 20150112 0 번째 기사: ' 사우디, 올해 경제 성장률 2.5% 전망…기대감 낮아져 '완료
# 20150112 0 번째 기사: ' [조현아 공판]① 항로변경죄 공방이 최대 쟁점 '완료
# 20150112 0 번째 기사: ' 女王의 옛 남자, 빙판으로 컴백 '완료
# 20150112 0 번째 기사: ' [최보식이 만난 사람] 원치 않는 길로 끌려가지 마라… 내 발로 내 길을 얼마든지 갈 수 있어 '완료
# 20150112 0 번째 기사: ' [조용헌 살롱] [972] 어미 고래와 機張(기장)미역 '완료
# 20150112 0 번째 기사: ' [朝鮮칼럼 The Column] 종교 분쟁은 神이 아닌 사람 탓이다 '완료
# 20150112 0 번째 기사: ' [일사일언] 3원짜리 예술 작품 '완료
# 20150112 0 번째 기사: ' [기자의 시각] 흡연의 品格 '완료
# 20150112 0 번째 기사: ' [동서남북] 그릇된 經濟 논리 꺾은 '한국의 스티븐 호킹' '완료
# 20150112 0 번째 기사: ' [만물상] 日 교과서 '위안부 지우기' '완료
# 20150112 0 번째 기사: ' [가슴으로 읽는 한시] 눈 속에서 홀로 술을 마시다 '완료
# 20150112 0 번째 기사: ' 狂氣에 휩싸인 세상… 아직도 유토피아를 꿈꾸는가 '완료
# 20150112 0 번째 기사: ' 차도르와 비키니 사이… 테러범의 여인이 사라졌다 '완료
# 20150112 0 번째 기사: ' [자구 노력없이 安住하는 지상파] 가족 시간대에도… 막장드라마 집착하는 지상파 '완료
# 20150112 0 번째 기사: ' 朴정부 2년도 안돼… 민정수석 3명 교체 '완료
# 20150112 0 번째 기사: ' 中, 3D프린터·드론시장까지 先占 노린다 '완료
# 20150112 0 번째 기사: ' [글로벌 경제현장] 불황 끝 안 보이는 PIGS(포르투갈·이탈리아·그리스·스페인)… 低유가로 본격 디플레 우려까지 '완료
# 20150112 0 번째 기사: ' [글로벌 경제현장] 빚 탕감 요구하는 급진 좌파, 총선서 승리할 가능성 커져… '그렉시트' 확률 0→ 17%로 '완료
# 20150112 0 번째 기사: ' 문학 관련 작품 읽기·아침자습 140시간 채우기…나와 한 약속, 끈기있게 지켜나가세요 '완료
# 20150112 0 번째 기사: ' [강남대성학원] 서울 강남역에 새 둥지… '강남대성'에서 큰 꿈 펼쳐라 '완료
# 20150112 0 번째 기사: ' [강남대성학원] 강남대성학원의 경쟁력… 1년에 두 번씩 강사 평가 '검증된 강의' '완료
# 20150112 0 번째 기사: ' [기숙학원 탐방｜서울케이스사관학원] 담임 강사 함께 숙식하며 '학습·생활' 철저히 관리 '완료
# 20150112 0 번째 기사: ' [기숙학원 탐방｜청솔기숙학원본원] 수준별 복습 시스템으로 성적 향상 도와 '완료
# 20150112 0 번째 기사: ' "넓은 세상서 다양한 도전… 내게 맞는 적성 찾을 수 있죠" '완료
# 20150112 0 번째 기사: ' 밝고 강렬한 색채… 가족과 함께 특별한 체험해 보세요 '완료
# 20150112 0 번째 기사: ' [이재호 교수의 'ICT 창의력' 키우는 법] '5가지 원칙'에 맞춰 일상 속 문제 해결해 보세요 '완료
# 20150112 0 번째 기사: ' [강남대성학원] 2015 수능 만점자 5명… 6년 연속 수능 수석 배출 '완료
# 20150112 0 번째 기사: ' [강남대성학원] "하루하루 꾸준히, 하나하나 치열하게… 1년 후 노력한 결과 나올겁니다" '완료
# 20150112 0 번째 기사: ' [리빙포인트] 밀가루 보송보송 보관 '완료
# 20150112 0 번째 기사: ' [자구 노력없이 安住하는 지상파] 다른데서 뜨면 갖다 베끼기만 '완료
# 20150112 0 번째 기사: ' [자구 노력없이 安住하는 지상파] 지상파, 외주社가 받은 협찬금 떼가고 과태료 떠넘기기도 '완료
# 20150112 0 번째 기사: ' [TV조선 ch19] 30년 만의 양육비 청구 '완료
# 20150112 0 번째 기사: ' 삼성화재 '獨走' '완료
# 20150112 0 번째 기사: ' 2년 연속 '별중의 별' 김선형… 토종 선수론 처음 '완료
# 20150112 0 번째 기사: ' '병역 맘고생' 털려는 듯 … 배상문, 새해 첫 PGA 맹타 '완료
# 20150112 0 번째 기사: ' 이변은 없었다… 강호 이란도 첫승 신고 '완료
# 20150112 0 번째 기사: ' "내일 더 강해지겠다" '완료
# 20150112 0 번째 기사: ' LA行 류현진 "부상 없이 200이닝 채울 것" '완료
# 20150112 0 번째 기사: ' [제19회 LG배 조선일보 기왕전] 검토실의 喊聲 '완료
# 20150112 0 번째 기사: ' 모굴스키, 평창 메달 턱밑까지 점프 '완료
# 20150112 0 번째 기사: ' [발언대] 국력·통일 위해 海外派兵 적극 나서자 '완료
# 20150112 0 번째 기사: ' [시론] '내 안의 敵'과 싸우는 프랑스 '완료
# 20150112 0 번째 기사: ' [금주의 공연, 이유 있는 선택] '서울바로크합주단 창단 50주년 특별 연주회' 외 '완료
# 20150112 0 번째 기사: ' [연극 리뷰] 죽음을 동경한 소년, '소녀 조르바'를 만났네 '완료
# 20150112 0 번째 기사: ' "극단적 左右대립, 仁義·행복으로 풀자" '완료
# 20150112 0 번째 기사: ' "숟가락, 고려 이후에 생필품 됐다" '완료
# 20150112 0 번째 기사: ' 현실 담은 문학이 돌아왔다, 분노와 함께 '완료
# 20150112 0 번째 기사: ' 사랑과 죽음은 하나 '완료
# 20150112 0 번째 기사: ' 佛경찰, 15분 간격으로 형제 테러범과 식품점 인질극 진압 '완료
# 20150112 0 번째 기사: ' [오늘의 세상] '적대국' 이·팔 頂上 함께 팔짱… 反테러 앞에 인종도 종교도 없었다 '완료
# 20150112 0 번째 기사: ' [깨알지식] 美재무차관이 CIA 2인자로 가는 까닭은 '완료
# 20150112 0 번째 기사: ' 아베 정부, '무라야마 담화' 改惡할듯 '완료
# 20150112 0 번째 기사: ' [월드 톡톡] 클린턴 부부 또 '性추문 악몽'? '완료
# 20150112 0 번째 기사: ' "韓美훈련 중단하면 核실험 중단" 北제안에 美 "암묵적 위협" 거부 '완료
# 20150112 0 번째 기사: ' 홍콩 최고 富豪(부호) 리카싱, 홍콩 떠나나 '완료
# 20150112 0 번째 기사: ' '이슬람 테러'에 맞서 인질 15명 구한 무슬림 점원(식품점 근무 20대 청년) '완료
# 20150112 0 번째 기사: ' 스프링클러 없고 건물 간격 좁고… 위험 방치한 '도시형 주택' 참사 '완료
# 20150112 0 번째 기사: ' 쉬는 날, 주민 13명 구한 새내기 소방관 '완료
# 20150112 0 번째 기사: ' [온실가스 배출권 거래] 환경부 "할당량 적다는 企業불만 납득안돼" '완료
# 20150112 0 번째 기사: ' 오늘·내일 일교차 커… 목도리 챙겨 출근하세요 '완료
# 20150112 0 번째 기사: ' 편의점 內 '담배 광고' 금지… 올 상반기 法개정 '완료
# 20150112 0 번째 기사: ' 機內 난동 바비킴, 탑승 전 다른 사람 비행기표 제시했는데도… 보안검색·출국심사·탑승구 어디서도 체크 안돼 '완료
# 20150112 0 번째 기사: ' 한국GM 10만대 리콜 조치 '완료
# 20150112 0 번째 기사: ' 에어아시아機 한국인 부부 시신 확인 '완료
# 20150112 0 번째 기사: ' '從北콘서트' 강제출국… LA공항선 左·右단체 충돌 '완료
# 20150112 0 번째 기사: ' 家長에 살해된 서초동 母女 시신서 수면제 '완료
# 20150112 0 번째 기사: ' [자구 노력없이 安住하는 지상파] 지상파, 헐값에 외주社 저작권 獨食 [반론보도문 포함] '완료
# 20150112 0 번째 기사: ' 장석효 가스公 사장 辭意… 산자부는 解任절차 진행 '완료
# 20150112 0 번째 기사: ' 김관진 국가안보실장 조만간 중국 방문 '완료
# 20150112 0 번째 기사: ' [통일이 미래다] 市場 커지면 시장 때리는 北… 경제개혁 번번이 실패 '완료
# 20150112 0 번째 기사: ' [통일이 미래다] "北, 중국식 개방땐 소득(1인당 GDP) 1만달러 가능" '완료
# 20150112 0 번째 기사: ' [통일이 미래다] "北, 이대로 가면 아프리카 최빈국 수준 전락" '완료
# 20150112 0 번째 기사: ' [통일이 미래다] "김정은, 젊고 神格化 덜 돼… 등소평처럼 개혁개방 가능성" '완료
# 20150112 0 번째 기사: ' [통일이 미래다] "北 서서히 변하는 중… 학교에서 영어·시장경제 배워" '완료
# 20150112 0 번째 기사: ' [오늘의 세상] "테러는 反문명적 범죄" 朴대통령, 佛에 위로전문 '완료
# 20150112 0 번째 기사: ' 朴대통령 오늘 회견… 文件유감 표명, 人的쇄신 입장도 밝힐 듯 '완료
# 20150112 0 번째 기사: ' "180만원짜리 의자 사고 40만원으로… 청와대, 高價 물건들 허위 등록했다" '완료
# 20150112 0 번째 기사: ' 대선 후보였던 정동영 脫黨 '완료
# 20150112 0 번째 기사: ' 새정치聯 대표 선거, 본격 레이스 시작 '완료
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-42-1f2fd6240099> in <module>
#       1 browser = webdriver.Firefox()
# ----> 2 contemporary_chosun_crawler(urls)
#
# <ipython-input-41-06b5da1b778c> in contemporary_chosun_crawler(urls)
#      80     for url in urls:
#      81         browser.get(url)
# ---> 82         page_browser(url, article_list)
#
# <ipython-input-41-06b5da1b778c> in page_browser(url, article_list)
#      70             page_url = url + page
#      71             browser.get(page_url)
# ---> 72         list_extractor(page_url, article_list, date)
#      73         i += 1
#      74         page = "&pn=" + str(i)
#
# <ipython-input-41-06b5da1b778c> in list_extractor(page_url, article_list, date)
#      60                 else:
#      61                     article_urls.append(article.find_elements_by_tag_name("a")[0].get_attribute("href"))
# ---> 62     article_extractor(article_urls, article_list, date)
#      63
#      64 def page_browser(url, article_list): # browsing pages of that date
#
# <ipython-input-41-06b5da1b778c> in article_extractor(article_urls, article_list, date)
#      27     for article in article_urls:
#      28         a = Article()
# ---> 29         browser.get(article)
#      30         title_exist = len(browser.find_elements_by_id("news_title_text_id"))
#      31         cat_exist = len(browser.find_elements_by_id("news_cat_trig_id"))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: Timeout loading page after 300000ms
